# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshGujarathi7/files/blob/main/research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, zipfile
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import data_table
data_table.enable_dataframe_formatter()

#! pip install geopandas
# !pip install mapclassify
import geopandas as gpd
import mapclassify

# %%
import zipfile
import os
# !wget -q -O colombia.zip https://drive.google.com/uc?id=1aEtQW8Xlh8XwhYYPFX2A8g_vTltUmCKa
zip_file_path = 'colombia.zip'
if os.path.exists(zip_file_path):
    zip_ref = zipfile.ZipFile(zip_file_path, 'r')
    zip_ref.extractall()
    zip_ref.close()

# %% [markdown]
# NOW WE NEED TO WRITE THE CODE FROM BOTTOM

# %%
#communities in cali columbia
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/COMUNAS/Comunas.shp')
obs.plot()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-3f10a995bf8a> in <cell line: 2>()
#       1 #communities in cali columbia
# ----> 2 obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/COMUNAS/Comunas.shp')
#       3 obs.plot()
#
# /usr/local/lib/python3.10/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     263         # otherwise still download manually because pyogrio/fiona don't support
#     264         # all types of urls (https://github.com/geopandas/geopandas/issues/2908)
# --> 265         with urllib.request.urlopen(filename) as response:
#     266             if not response.headers.get("Accept-Ranges") == "bytes":
#     267                 filename = response.read()
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
# ...

# %%
#citywise cali coloumbia
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/Zonas_cali/barrios_wgs84_4.shp')
obs.plot()
# Out:
# <Axes: >

# %%
#urbanization
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/ZONA%20DE%20EXPANSION/Division_suelo_expansion.shp')
obs.plot()
# Out:
# <Axes: >

# %%
#playgrounds
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/SECRE%20DEPORTE/DEPORTE/Escenarios_deportivos.shp')
obs.plot()
# Out:
# <Axes: >

# %%
#road transportation
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/VIAS/Jerarquizacion_vial.shp')
obs.plot()
# Out:
# <Axes: >

# %%
#hill area
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/VEREDAS/Corregimientos.shp')
obs.plot()
# Out:
# <Axes: >

# %%
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/VEREDAS/Corregimientos.shp')
obs.plot()
# Out:
# <Axes: >

# %%
#bus stations of cali columbia
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/SITM%20MIO/ESTACIONES/Estaciones_MIO_.shp')
obs.plot()
# Out:
# <Axes: >

# %%
#bus routes in cali columbia
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/SITM%20MIO/ALIMENTADORAS/Rutas_alimentadoras_SITM_MIO.shp')
obs.plot()
# Out:
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ...

# %%
#bus routes
obs = gpd.read_file('https://github.com/Athang9/Cali_Columbia_Research/raw/main/SITM%20MIO/PRETRONCALES/Rutas_pretroncales_SITM_MIO.shp')
obs.plot()
# Out:
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ERROR:fiona.ogrext:year 0 is out of range
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 355, in fiona.ogrext.FeatureBuilder.build
# ValueError: year 0 is out of range
# ...

# %%
print('hey')
# Out:
# hey
